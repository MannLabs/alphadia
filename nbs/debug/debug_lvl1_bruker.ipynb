# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import neptune.new as neptune
import alphatims.bruker as bruker

from alphabase.spectral_library.base import SpecLibBase
from alphadia.extraction import data, planning, workflow
from alphadia.extraction.workflow import manager, peptidecentric



raw_files = [
    '/Users/georgwallmann/Documents/data/performance_tests/bruker/raw_data/timstof_lf_diap_syp/20230502_TIMS05_PaSk_SA_HeLa_21min_diaP_12scans_S2-A3_1_2089.d',
]
output_location = '/Users/georgwallmann/Documents/data/performance_tests/bruker/outputs/timstof_lf_diaPASEF'
# Out:
# /var/folders/lc/9594t94d5b5_gn0y04w1jh980000gn/T/ipykernel_88368/3772214903.py:8: NeptuneDeprecationWarning: You're importing the Neptune client library via the deprecated `neptune.new` module, which will be removed in a future release. Import directly from `neptune` instead.
#   import neptune.new as neptune
# WARNING:root:WARNING: Temp mmap arrays are written to /var/folders/lc/9594t94d5b5_gn0y04w1jh980000gn/T/temp_mmap_29om1iuk. Cleanup of this folder is OS dependant, and might need to be triggered manually! Current space: 545,135,869,952
# WARNING:root:WARNING: No Bruker libraries are available for this operating system. Mobility and m/z values need to be estimated. While this estimation often returns acceptable results with errors < 0.02 Th, huge errors (e.g. offsets of 6 Th) have already been observed for some samples!

# %%
speclib = '/Users/georgwallmann/Documents/data/performance_tests/bruker/libraries/21min_Evosep_HeLa_BR14_48fractions_diaPASEF_py_diAID_2_egs.hdf'
test_lib = SpecLibBase()
test_lib.load_hdf(speclib, load_mod_seq=True)

# %%
plan = planning.Plan(output_location, raw_files, test_lib)

plan.config['general']['reuse_calibration'] = False
plan.config['general']['save_figueres'] = False
plan.config['general']['thread_count'] = 10
plan.config['general']['astral_ms1'] = False
plan.config['library_loading']['channel_filter'] = '0'
plan.config['library_loading']['exclude_shared_ions'] = False
plan.config['calibration']['norm_rt_mode'] = 'linear'

plan.config['extraction_target']['target_num_candidates'] = 5
plan.config['extraction_target']['target_ms1_tolerance'] = 15
plan.config['extraction_target']['target_ms2_tolerance'] = 15
plan.config['extraction_target']['target_rt_tolerance'] = 150

plan.run()
# Out:
# 0:00:00.000196  PROGRESS:       _   _      _         ___ ___   _
# 0:00:00.000649  PROGRESS:      /_\ | |_ __| |_  __ _|   \_ _| /_\
# 0:00:00.001002  PROGRESS:     / _ \| | '_ \ ' \/ _` | |) | | / _ \
# 0:00:00.001410  PROGRESS:    /_/ \_\_| .__/_||_\__,_|___/___/_/ \_\
# 0:00:00.001777  PROGRESS:            |_|
# 0:00:00.002142  PROGRESS:
# 0:00:00.002556  INFO: loading default config from /Users/georgwallmann/Documents/git/alphadia/alphadia/extraction/../../misc/config/default.yaml
# 0:00:00.009707  PROGRESS: version: 1.3.1
# 0:00:00.010067  PROGRESS: hostname: Georgs-MacBook-Pro.local
# 0:00:00.010362  PROGRESS: date: 2023-09-23 13:44:32
# 0:00:05.971562  INFO: renaming precursor_columns columns
# 0:00:05.972715  INFO: renaming fragment_columns columns
# 0:00:05.973264  INFO: ========= Library Stats =========
# 0:00:05.973783  INFO: Number of precursors: 460,153
# 0:00:06.034028  INFO: 	thereof targets:230,483
# 0:00:06.034528  INFO: 	thereof decoys: 229,670
# 0:00:06.037904  INFO: Number of elution groups: 231,149
# 0:00:06.038274  INFO: 	average size: 1.99
# 0:00:06.053314  INFO: Number of proteins: 9,899
# 0:00:06.053816  WARNING: no channel column was found, will assume only one channel
# 0:00:06.054200  INFO: Isotopes Distribution for 6 isotopes
# 0:00:06.054716  INFO: =================================
# 0:00:06.055772  WARNING: no precursor_idx column found, creating one
# 0:00:06.056768  WARNING: no channel column found, creating one
# /Users/georgwallmann/Documents/git/alphadia/alphadia/extraction/workflow/base.py:58: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   self.neptune = neptune.init_run(
# https://app.neptune.ai/MannLabs/alphaDIA/e/AL-411
# 0:00:08.316381  INFO: Importing data from /Users/georgwallmann/Documents/data/performance_tests/bruker/raw_data/timstof_lf_diap_syp/20230502_TIMS05_PaSk_SA_HeLa_21min_diaP_12scans_S2-A3_1_2089.d
# 0:00:08.316951  INFO: Using .d import for /Users/georgwallmann/Documents/data/performance_tests/bruker/raw_data/timstof_lf_diap_syp/20230502_TIMS05_PaSk_SA_HeLa_21min_diaP_12scans_S2-A3_1_2089.d
# 0:00:08.317409  INFO: Reading frame metadata for /Users/georgwallmann/Documents/data/performance_tests/bruker/raw_data/timstof_lf_diap_syp/20230502_TIMS05_PaSk_SA_HeLa_21min_diaP_12scans_S2-A3_1_2089.d
# 0:00:08.447675  INFO: Reading 11,812 frames with 1,479,051,420 detector events for /Users/georgwallmann/Documents/data/performance_tests/bruker/raw_data/timstof_lf_diap_syp/20230502_TIMS05_PaSk_SA_HeLa_21min_diaP_12scans_S2-A3_1_2089.d
# 100%|██████████| 11812/11812 [00:05<00:00, 2027.88it/s]
# 0:00:14.339834  INFO: Indexing /Users/georgwallmann/Documents/data/performance_tests/bruker/raw_data/timstof_lf_diap_syp/20230502_TIMS05_PaSk_SA_HeLa_21min_diaP_12scans_S2-A3_1_2089.d...
# 0:00:14.340936  INFO: Bruker DLL not available, estimating mobility values
# 0:00:14.341335  INFO: Bruker DLL not available, estimating mz values
# 0:00:14.343111  INFO: Indexing quadrupole dimension
# 0:00:14.471452  INFO: Transposing detector events
# 100%|██████████| 20/20 [00:05<00:00,  3.97it/s]
# 0:00:21.909839  INFO: Finished transposing data
# 0:00:22.007833  INFO: Successfully imported data from /Users/georgwallmann/Documents/data/performance_tests/bruker/raw_data/timstof_lf_diap_syp/20230502_TIMS05_PaSk_SA_HeLa_21min_diaP_12scans_S2-A3_1_2089.d
# 0:00:22.104803  INFO: ========= Initializing Calibration Manager =========
# 0:00:22.105396  INFO: loading calibration config
# 0:00:22.105868  INFO: found 2 calibration groups
# 0:00:22.106315  INFO: Calibration group :fragment, found 1 estimator(s)
# 0:00:22.106804  INFO: Calibration group :precursor, found 3 estimator(s)
# 0:00:22.107159  INFO: ====================================================
# 0:00:22.107549  INFO: ========= Initializing Optimization Manager =========
# 0:00:22.107915  INFO: initial parameter: fwhm_rt = 5
# 0:00:22.108235  INFO: initial parameter: fwhm_mobility = 0.01
# 0:00:22.108534  INFO: ====================================================
# 0:00:22.108954  PROGRESS: Initializing workflow 20230502_TIMS05_PaSk_SA_HeLa_21min_diaP_12scans_S2-A3_1_2089
# 0:00:22.109203  INFO: ========= Initializing Optimization Manager =========
# 0:00:22.109538  INFO: initial parameter: current_epoch = 0
# 0:00:22.109885  INFO: initial parameter: current_step = 0
# 0:00:22.110250  INFO: initial parameter: ms1_error = 30
# 0:00:22.110542  INFO: initial parameter: ms2_error = 30
# 0:00:22.110892  INFO: initial parameter: rt_error = 240
# 0:00:22.111108  INFO: initial parameter: mobility_error = 0.08
# 0:00:22.111676  INFO: initial parameter: column_type = library
# 0:00:22.111934  INFO: initial parameter: num_candidates = 2
# 0:00:22.112290  INFO: initial parameter: recalibration_target = 200
# 0:00:22.112587  INFO: initial parameter: accumulated_precursors = 0
# 0:00:22.112871  INFO: initial parameter: accumulated_precursors_01FDR = 0
# 0:00:22.113303  INFO: initial parameter: accumulated_precursors_001FDR = 0
# 0:00:22.113687  INFO: ====================================================
# 0:00:22.113928  INFO: ========= Initializing FDR Manager =========
# 0:00:22.114222  INFO: ====================================================
# 0:00:22.114633  PROGRESS: Applying channel filter using only: [0]
# 0:00:22.225124  INFO: calibration group: precursor, predicting mz
# 0:00:22.225712  WARNING: mz prediction was skipped as it has not been fitted yet
# 0:00:22.225960  INFO: calibration group: precursor, predicting rt
# 0:00:22.226147  WARNING: rt prediction was skipped as it has not been fitted yet
# 0:00:22.226318  INFO: calibration group: precursor, predicting mobility
# 0:00:22.226671  WARNING: mobility prediction was skipped as it has not been fitted yet
# 0:00:22.226986  INFO: calibration group: fragment, predicting mz
# 0:00:22.227262  WARNING: mz prediction was skipped as it has not been fitted yet
# /Users/georgwallmann/Documents/git/alphadia/alphadia/extraction/workflow/peptidecentric.py:305: NeptuneUnsupportedType: You're attempting to log a type that is not directly supported by Neptune (<class 'NoneType'>).
#         Convert the value to a supported type, such as a string or float, or use stringify_unsupported(obj)
#         for dictionaries or collections that contain unsupported values.
#         For more, see https://docs.neptune.ai/help/value_of_unsupported_type
#   self.neptune[f"eval/{key}"].log(value)
# 0:00:22.230856  PROGRESS: === Epoch 0, step 0, extracting elution groups 0 to 4000 ===
# 0:00:22.237774  PROGRESS: MS1 error: 30, MS2 error: 30, RT error: 240, Mobility error: 0.08
# 0:00:23.701445  INFO: Duty cycle consists of 13 frames, 1.39 seconds cycle time
# 0:00:23.701973  INFO: Duty cycle consists of 928 scans, 0.00065 1/K_0 resolution
# 0:00:23.702255  INFO: FWHM in RT is 5.00 seconds, sigma is 0.77
# 0:00:23.702525  INFO: FWHM in mobility is 0.010 1/K_0, sigma is 6.57
# 0:00:24.470848  INFO: Starting candidate selection
# 100%|██████████| 7965/7965 [01:27<00:00, 90.58it/s]
# 0:01:54.093226  INFO: Finished candidate selection
# 0:01:55.313703  INFO: Starting candidate scoring
#   0%|          | 0/13932 [00:00<?, ?it/s]/Users/georgwallmann/Documents/git/alphatims/alphatims/utils.py:583: NumbaTypeSafetyWarning: unsafe cast from float64 to float32. Precision may be lost.
#   numba_func(i, *args)
# /Users/georgwallmann/Documents/git/alphatims/alphatims/utils.py:583: NumbaTypeSafetyWarning: unsafe cast from int64 to float32. Precision may be lost.
#   numba_func(i, *args)
# 100%|██████████| 13932/13932 [01:03<00:00, 221.10it/s]
# 0:03:00.196693  WARNING: base_width_mobility has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.198345  WARNING: base_width_rt has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.199154  WARNING: rt_observed has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.200114  WARNING: mobility_observed has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.200750  WARNING: mono_ms1_intensity has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.201829  WARNING: top_ms1_intensity has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.202464  WARNING: sum_ms1_intensity has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.203507  WARNING: weighted_ms1_intensity has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.204180  WARNING: weighted_mass_deviation has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.204817  WARNING: weighted_mass_error has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.205348  WARNING: mz_observed has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.205999  WARNING: mono_ms1_height has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.206612  WARNING: top_ms1_height has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.207629  WARNING: sum_ms1_height has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.208098  WARNING: weighted_ms1_height has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.208801  WARNING: isotope_intensity_correlation has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.209313  WARNING: isotope_height_correlation has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.209931  WARNING: n_observations has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.210522  WARNING: intensity_correlation has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.211057  WARNING: height_correlation has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.211498  WARNING: intensity_fraction has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.211881  WARNING: height_fraction has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.212669  WARNING: intensity_fraction_weighted has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.213366  WARNING: height_fraction_weighted has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.214351  WARNING: mean_observation_score has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.215054  WARNING: sum_b_ion_intensity has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.215912  WARNING: sum_y_ion_intensity has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.216691  WARNING: diff_b_y_ion_intensity has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.217489  WARNING: fragment_frame_correlation has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.218369  WARNING: top3_frame_correlation has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.219184  WARNING: template_frame_correlation has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.221115  WARNING: top3_b_ion_correlation has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.223092  WARNING: top3_y_ion_correlation has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.224187  WARNING: cycle_fwhm has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.225875  WARNING: mobility_fwhm has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.226804  WARNING: n_b_ions has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.228210  WARNING: n_y_ions has 7 NaNs ( 0.05 % out of 13932)
# 0:03:00.229947  WARNING: f_masked has 7 NaNs ( 0.05 % out of 13932)
# 0:03:01.113786  INFO: Finished candidate scoring
# 0:03:01.182574  INFO: number of dfs in features: 1, total number of features: 13932
# 0:03:01.183184  INFO: performing precursor_channel_wise FDR with 39 features
# 0:03:01.183827  INFO: Decoy channel: -1
# 0:03:01.184175  INFO: Competetive: true,
# 0:03:01.203005  WARNING: dropped 3 target PSMs due to missing features
# 0:03:01.203684  WARNING: dropped 4 decoy PSMs due to missing features
# 0:03:03.930334  INFO: Post FDR iterations: 22
# 0:03:04.160045  INFO: Test AUC: 0.583
# 0:03:04.160525  INFO: Train AUC: 0.656
# 0:03:04.160794  INFO: AUC difference: 11.14%
# 0:03:04.160995  WARNING: AUC difference > 5%. This may indicate overfitting.
# 0:03:04.510497  PROGRESS: === checking if recalibration conditions were reached, target 200 precursors ===
# 0:03:04.512126  PROGRESS: ============================= Precursor FDR =============================
# 0:03:04.512411  PROGRESS: Total precursors accumulated: 3,986
# 0:03:04.512713  PROGRESS: Target precursors: 2,722 (68.29%)
# 0:03:04.512963  PROGRESS: Decoy precursors: 1,264 (31.71%)
# 0:03:04.513457  PROGRESS:
# 0:03:04.513889  PROGRESS: Precursor Summary:
# 0:03:04.515668  PROGRESS: Channel   0:	 0.05 FDR:   495; 0.01 FDR:   353; 0.001 FDR:   315
# 0:03:04.516057  PROGRESS:
# 0:03:04.516378  PROGRESS: Protein Summary:
# 0:03:04.519328  PROGRESS: Channel   0:	 0.05 FDR:   447; 0.01 FDR:   320; 0.001 FDR:   290
# 0:03:04.519686  PROGRESS: =========================================================================
# 0:03:04.521905  INFO: calibration group: precursor, fitting mz estimator
# 0:03:04.670007  INFO: calibration group: precursor, fitting rt estimator
# 0:03:04.813378  INFO: calibration group: precursor, fitting mobility estimator
# 0:03:04.966063  INFO: calibration group: fragment, fitting mz estimator
# 0:03:05.156615  INFO: calibration group: precursor, predicting mz
# 0:03:05.215418  INFO: calibration group: precursor, predicting rt
# 0:03:05.331748  INFO: calibration group: precursor, predicting mobility
# 0:03:05.381127  INFO: calibration group: fragment, predicting mz
# 0:03:06.199577  PROGRESS: === Epoch 1, step 0, extracting elution groups 0 to 4000 ===
# 0:03:06.211248  PROGRESS: MS1 error: 15, MS2 error: 15, RT error: 150, Mobility error: 0.04
# 0:03:06.213658  INFO: Duty cycle consists of 13 frames, 1.39 seconds cycle time
# 0:03:06.214139  INFO: Duty cycle consists of 928 scans, 0.00065 1/K_0 resolution
# 0:03:06.214364  INFO: FWHM in RT is 4.60 seconds, sigma is 0.70
# 0:03:06.214877  INFO: FWHM in mobility is 0.010 1/K_0, sigma is 6.34
# 0:03:06.217938  INFO: Starting candidate selection
# 100%|██████████| 7955/7955 [00:16<00:00, 479.95it/s]
# 0:03:23.390595  INFO: Finished candidate selection
# 0:03:23.732509  INFO: Starting candidate scoring
# 100%|██████████| 29574/29574 [00:05<00:00, 5184.26it/s]
# 0:03:30.212917  WARNING: base_width_mobility has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.214275  WARNING: base_width_rt has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.214857  WARNING: rt_observed has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.215850  WARNING: mobility_observed has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.218089  WARNING: mono_ms1_intensity has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.218712  WARNING: top_ms1_intensity has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.219453  WARNING: sum_ms1_intensity has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.220415  WARNING: weighted_ms1_intensity has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.221411  WARNING: weighted_mass_deviation has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.222215  WARNING: weighted_mass_error has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.223254  WARNING: mz_observed has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.223942  WARNING: mono_ms1_height has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.224538  WARNING: top_ms1_height has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.225193  WARNING: sum_ms1_height has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.225687  WARNING: weighted_ms1_height has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.226392  WARNING: isotope_intensity_correlation has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.227186  WARNING: isotope_height_correlation has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.228196  WARNING: n_observations has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.229149  WARNING: intensity_correlation has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.229870  WARNING: height_correlation has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.230440  WARNING: intensity_fraction has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.231274  WARNING: height_fraction has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.232115  WARNING: intensity_fraction_weighted has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.232574  WARNING: height_fraction_weighted has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.233330  WARNING: mean_observation_score has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.233743  WARNING: sum_b_ion_intensity has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.234480  WARNING: sum_y_ion_intensity has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.235231  WARNING: diff_b_y_ion_intensity has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.235654  WARNING: fragment_frame_correlation has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.236446  WARNING: top3_frame_correlation has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.237007  WARNING: template_frame_correlation has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.237513  WARNING: top3_b_ion_correlation has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.238538  WARNING: top3_y_ion_correlation has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.239175  WARNING: cycle_fwhm has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.240055  WARNING: mobility_fwhm has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.240640  WARNING: n_b_ions has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.241469  WARNING: n_y_ions has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.242399  WARNING: f_masked has 7 NaNs ( 0.02 % out of 29574)
# 0:03:30.353758  INFO: Finished candidate scoring
# 0:03:30.492005  INFO: number of dfs in features: 1, total number of features: 29574
# 0:03:30.492525  INFO: performing precursor_channel_wise FDR with 39 features
# 0:03:30.492735  INFO: Decoy channel: -1
# 0:03:30.492974  INFO: Competetive: true,
# 0:03:30.528451  WARNING: dropped 4 target PSMs due to missing features
# 0:03:30.528911  WARNING: dropped 3 decoy PSMs due to missing features
# 0:03:30.532663  INFO: Pre FDR iterations: 22
# 0:03:35.488927  INFO: Post FDR iterations: 20
# 0:03:35.578812  INFO: Test AUC: 0.587
# 0:03:35.579342  INFO: Train AUC: 0.652
# 0:03:35.579590  INFO: AUC difference: 9.95%
# 0:03:35.579854  WARNING: AUC difference > 5%. This may indicate overfitting.
# 0:03:35.931902  PROGRESS: === checking if recalibration conditions were reached, target 400 precursors ===
# 0:03:35.933276  PROGRESS: ============================= Precursor FDR =============================
# 0:03:35.933777  PROGRESS: Total precursors accumulated: 3,985
# 0:03:35.934036  PROGRESS: Target precursors: 2,928 (73.48%)
# 0:03:35.934291  PROGRESS: Decoy precursors: 1,057 (26.52%)
# 0:03:35.934485  PROGRESS:
# 0:03:35.934697  PROGRESS: Precursor Summary:
# 0:03:35.937163  PROGRESS: Channel   0:	 0.05 FDR:   988; 0.01 FDR:   760; 0.001 FDR:   546
# 0:03:35.937513  PROGRESS:
# 0:03:35.937778  PROGRESS: Protein Summary:
# 0:03:35.939922  PROGRESS: Channel   0:	 0.05 FDR:   827; 0.01 FDR:   644; 0.001 FDR:   478
# 0:03:35.940187  PROGRESS: =========================================================================
# 0:03:35.942436  INFO: calibration group: precursor, fitting mz estimator
# 0:03:36.103381  INFO: calibration group: precursor, fitting rt estimator
# 0:03:36.250839  INFO: calibration group: precursor, fitting mobility estimator
# 0:03:36.408651  INFO: calibration group: fragment, fitting mz estimator
# 0:03:36.941398  INFO: calibration group: precursor, predicting mz
# 0:03:36.995517  INFO: calibration group: precursor, predicting rt
# 0:03:37.124646  INFO: calibration group: precursor, predicting mobility
# 0:03:37.175510  INFO: calibration group: fragment, predicting mz
# 0:03:37.946322  PROGRESS: === Epoch 2, step 0, extracting elution groups 0 to 4000 ===
# 0:03:37.955999  PROGRESS: MS1 error: 15, MS2 error: 15, RT error: 150, Mobility error: 0.04
# 0:03:37.958298  INFO: Duty cycle consists of 13 frames, 1.39 seconds cycle time
# 0:03:37.958693  INFO: Duty cycle consists of 928 scans, 0.00065 1/K_0 resolution
# 0:03:37.959164  INFO: FWHM in RT is 4.26 seconds, sigma is 0.65
# 0:03:37.959636  INFO: FWHM in mobility is 0.008 1/K_0, sigma is 5.22
# 0:03:37.961231  INFO: Starting candidate selection
# 100%|██████████| 7932/7932 [00:15<00:00, 497.22it/s]
# 0:03:54.804935  INFO: Finished candidate selection
# 0:03:55.162231  INFO: Starting candidate scoring
# 100%|██████████| 28311/28311 [00:05<00:00, 5185.75it/s]
# 0:04:01.065479  WARNING: base_width_mobility has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.066340  WARNING: base_width_rt has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.067209  WARNING: rt_observed has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.068069  WARNING: mobility_observed has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.068763  WARNING: mono_ms1_intensity has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.069520  WARNING: top_ms1_intensity has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.070344  WARNING: sum_ms1_intensity has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.070827  WARNING: weighted_ms1_intensity has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.071472  WARNING: weighted_mass_deviation has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.072065  WARNING: weighted_mass_error has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.072855  WARNING: mz_observed has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.073348  WARNING: mono_ms1_height has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.074053  WARNING: top_ms1_height has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.074535  WARNING: sum_ms1_height has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.075101  WARNING: weighted_ms1_height has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.075887  WARNING: isotope_intensity_correlation has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.076459  WARNING: isotope_height_correlation has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.076981  WARNING: n_observations has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.077613  WARNING: intensity_correlation has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.078409  WARNING: height_correlation has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.079088  WARNING: intensity_fraction has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.079969  WARNING: height_fraction has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.080751  WARNING: intensity_fraction_weighted has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.081367  WARNING: height_fraction_weighted has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.082131  WARNING: mean_observation_score has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.082609  WARNING: sum_b_ion_intensity has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.083683  WARNING: sum_y_ion_intensity has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.084332  WARNING: diff_b_y_ion_intensity has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.085238  WARNING: fragment_frame_correlation has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.086000  WARNING: top3_frame_correlation has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.086745  WARNING: template_frame_correlation has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.087276  WARNING: top3_b_ion_correlation has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.087977  WARNING: top3_y_ion_correlation has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.089072  WARNING: cycle_fwhm has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.089626  WARNING: mobility_fwhm has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.090334  WARNING: n_b_ions has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.091129  WARNING: n_y_ions has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.092059  WARNING: f_masked has 11 NaNs ( 0.04 % out of 28311)
# 0:04:01.196606  INFO: Finished candidate scoring
# 0:04:01.325370  INFO: number of dfs in features: 1, total number of features: 28311
# 0:04:01.325910  INFO: performing precursor_channel_wise FDR with 39 features
# 0:04:01.326116  INFO: Decoy channel: -1
# 0:04:01.326354  INFO: Competetive: true,
# 0:04:01.361525  WARNING: dropped 6 target PSMs due to missing features
# 0:04:01.362107  WARNING: dropped 5 decoy PSMs due to missing features
# 0:04:01.365774  INFO: Pre FDR iterations: 20
# 0:04:09.055578  INFO: Post FDR iterations: 26
# 0:04:09.152487  INFO: Test AUC: 0.595
# 0:04:09.152989  INFO: Train AUC: 0.662
# 0:04:09.153378  INFO: AUC difference: 10.20%
# 0:04:09.153853  WARNING: AUC difference > 5%. This may indicate overfitting.
# 0:04:09.509020  PROGRESS: === checking if recalibration conditions were reached, target 600 precursors ===
# 0:04:09.510780  PROGRESS: ============================= Precursor FDR =============================
# 0:04:09.511302  PROGRESS: Total precursors accumulated: 3,975
# 0:04:09.511679  PROGRESS: Target precursors: 2,924 (73.56%)
# 0:04:09.512006  PROGRESS: Decoy precursors: 1,051 (26.44%)
# 0:04:09.512328  PROGRESS:
# 0:04:09.512802  PROGRESS: Precursor Summary:
# 0:04:09.514954  PROGRESS: Channel   0:	 0.05 FDR: 1,097; 0.01 FDR:   879; 0.001 FDR:   452
# 0:04:09.515308  PROGRESS:
# 0:04:09.515492  PROGRESS: Protein Summary:
# 0:04:09.518198  PROGRESS: Channel   0:	 0.05 FDR:   930; 0.01 FDR:   747; 0.001 FDR:   399
# 0:04:09.518553  PROGRESS: =========================================================================
# 0:04:09.521499  PROGRESS: === Epoch 2, step 1, extracting elution groups 4000 to 8000 ===
# 0:04:09.533158  PROGRESS: MS1 error: 15, MS2 error: 15, RT error: 150, Mobility error: 0.04
# 0:04:09.535392  INFO: Duty cycle consists of 13 frames, 1.39 seconds cycle time
# 0:04:09.535747  INFO: Duty cycle consists of 928 scans, 0.00065 1/K_0 resolution
# 0:04:09.536186  INFO: FWHM in RT is 4.26 seconds, sigma is 0.65
# 0:04:09.536774  INFO: FWHM in mobility is 0.008 1/K_0, sigma is 5.22
# 0:04:09.541545  INFO: Starting candidate selection
# 100%|██████████| 7945/7945 [00:15<00:00, 516.23it/s]
# 0:04:25.501275  INFO: Finished candidate selection
# 0:04:25.838460  INFO: Starting candidate scoring
# 100%|██████████| 28307/28307 [00:05<00:00, 5210.53it/s]
# 0:04:31.718040  WARNING: base_width_mobility has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.718721  WARNING: base_width_rt has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.719244  WARNING: rt_observed has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.720079  WARNING: mobility_observed has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.720944  WARNING: mono_ms1_intensity has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.721791  WARNING: top_ms1_intensity has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.722560  WARNING: sum_ms1_intensity has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.723050  WARNING: weighted_ms1_intensity has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.723795  WARNING: weighted_mass_deviation has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.724543  WARNING: weighted_mass_error has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.725287  WARNING: mz_observed has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.725947  WARNING: mono_ms1_height has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.726612  WARNING: top_ms1_height has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.727298  WARNING: sum_ms1_height has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.728191  WARNING: weighted_ms1_height has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.729030  WARNING: isotope_intensity_correlation has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.729523  WARNING: isotope_height_correlation has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.730144  WARNING: n_observations has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.730726  WARNING: intensity_correlation has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.731753  WARNING: height_correlation has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.732259  WARNING: intensity_fraction has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.733140  WARNING: height_fraction has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.734222  WARNING: intensity_fraction_weighted has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.735118  WARNING: height_fraction_weighted has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.735958  WARNING: mean_observation_score has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.736669  WARNING: sum_b_ion_intensity has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.737392  WARNING: sum_y_ion_intensity has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.738037  WARNING: diff_b_y_ion_intensity has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.738696  WARNING: fragment_frame_correlation has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.739417  WARNING: top3_frame_correlation has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.740124  WARNING: template_frame_correlation has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.740887  WARNING: top3_b_ion_correlation has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.742240  WARNING: top3_y_ion_correlation has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.743176  WARNING: cycle_fwhm has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.745676  WARNING: mobility_fwhm has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.748154  WARNING: n_b_ions has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.749612  WARNING: n_y_ions has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.750666  WARNING: f_masked has 9 NaNs ( 0.03 % out of 28307)
# 0:04:31.855532  INFO: Finished candidate scoring
# 0:04:31.989136  INFO: number of dfs in features: 2, total number of features: 56618
# 0:04:31.989634  INFO: performing precursor_channel_wise FDR with 39 features
# 0:04:31.989888  INFO: Decoy channel: -1
# 0:04:31.990168  INFO: Competetive: true,
# 0:04:32.051952  WARNING: dropped 10 target PSMs due to missing features
# 0:04:32.052430  WARNING: dropped 10 decoy PSMs due to missing features
# 0:04:32.058748  INFO: Pre FDR iterations: 26
# 0:04:43.079025  INFO: Post FDR iterations: 30
# 0:04:43.219110  INFO: Test AUC: 0.606
# 0:04:43.219633  INFO: Train AUC: 0.641
# 0:04:43.219907  INFO: AUC difference: 5.47%
# 0:04:43.220214  WARNING: AUC difference > 5%. This may indicate overfitting.
# 0:04:43.599010  PROGRESS: === checking if recalibration conditions were reached, target 600 precursors ===
# 0:04:43.600830  PROGRESS: ============================= Precursor FDR =============================
# 0:04:43.601255  PROGRESS: Total precursors accumulated: 7,926
# 0:04:43.601491  PROGRESS: Target precursors: 5,766 (72.75%)
# 0:04:43.601798  PROGRESS: Decoy precursors: 2,160 (27.25%)
# 0:04:43.602075  PROGRESS:
# 0:04:43.602532  PROGRESS: Precursor Summary:
# 0:04:43.605021  PROGRESS: Channel   0:	 0.05 FDR: 2,114; 0.01 FDR: 1,609; 0.001 FDR: 1,181
# 0:04:43.605344  PROGRESS:
# 0:04:43.605599  PROGRESS: Protein Summary:
# 0:04:43.608964  PROGRESS: Channel   0:	 0.05 FDR: 1,577; 0.01 FDR: 1,217; 0.001 FDR:   932
# 0:04:43.609457  PROGRESS: =========================================================================
# 0:04:43.611972  INFO: calibration group: precursor, fitting mz estimator
# 0:04:43.794335  INFO: calibration group: precursor, fitting rt estimator
# 0:04:43.970770  INFO: calibration group: precursor, fitting mobility estimator
# 0:04:44.160578  INFO: calibration group: fragment, fitting mz estimator
# 0:04:45.833860  INFO: calibration group: precursor, predicting mz
# 0:04:45.880081  INFO: calibration group: precursor, predicting rt
# 0:04:46.003959  INFO: calibration group: precursor, predicting mobility
# 0:04:46.053598  INFO: calibration group: fragment, predicting mz
# 0:04:46.874525  INFO: calibration group: precursor, predicting mz
# 0:04:46.921924  INFO: calibration group: precursor, predicting rt
# 0:04:47.045875  INFO: calibration group: precursor, predicting mobility
# 0:04:47.103193  INFO: calibration group: fragment, predicting mz
# 0:04:47.955353  INFO: calibration group: precursor, predicting mz
# 0:04:48.008319  INFO: calibration group: precursor, predicting rt
# 0:04:48.137441  INFO: calibration group: precursor, predicting mobility
# 0:04:48.188071  INFO: calibration group: fragment, predicting mz
# 0:04:48.933207  PROGRESS: MS1 error: 15, MS2 error: 15, RT error: 150, Mobility error: 0.04
# 0:04:49.002737  INFO: Duty cycle consists of 13 frames, 1.39 seconds cycle time
# 0:04:49.003254  INFO: Duty cycle consists of 928 scans, 0.00065 1/K_0 resolution
# 0:04:49.003562  INFO: FWHM in RT is 4.31 seconds, sigma is 0.66
# 0:04:49.004114  INFO: FWHM in mobility is 0.008 1/K_0, sigma is 5.26
# 0:04:49.009035  INFO: Starting candidate selection
# 100%|██████████| 460153/460153 [14:05<00:00, 544.02it/s]
# 0:19:11.557050  INFO: Finished candidate selection
# 0:19:13.208159  INFO: Starting candidate scoring
#  61%|██████    | 606/1000 [03:13<02:05,  3.14it/s]

# %%
for raw_name, dia_path, speclib in plan.get_run_data():
    pass

# %%
workflow = peptidecentric.PeptideCentricWorkflow(
    raw_name,
    plan.config,
    dia_path,
    speclib
)
# Out:
# https://app.neptune.ai/MannLabs/alphaDIA/e/AL-337
# 0:00:08.596494  INFO: Importing data from /Users/georgwallmann/Documents/data/testing/bruker/20230422_TIMS05_PaSk_MCT_SA_HeLa_mDIA_P001_diaP_pydiAID8_1300V_S2-E3_1_1819.d
# 0:00:08.597051  INFO: Using .d import for /Users/georgwallmann/Documents/data/testing/bruker/20230422_TIMS05_PaSk_MCT_SA_HeLa_mDIA_P001_diaP_pydiAID8_1300V_S2-E3_1_1819.d
# 0:00:08.597463  INFO: Reading frame metadata for /Users/georgwallmann/Documents/data/testing/bruker/20230422_TIMS05_PaSk_MCT_SA_HeLa_mDIA_P001_diaP_pydiAID8_1300V_S2-E3_1_1819.d
# 0:00:08.793820  INFO: Reading 17,438 frames with 1,635,017,608 detector events for /Users/georgwallmann/Documents/data/testing/bruker/20230422_TIMS05_PaSk_MCT_SA_HeLa_mDIA_P001_diaP_pydiAID8_1300V_S2-E3_1_1819.d
# 100%|██████████| 17438/17438 [00:07<00:00, 2446.79it/s]
# 0:00:16.016436  INFO: Indexing /Users/georgwallmann/Documents/data/testing/bruker/20230422_TIMS05_PaSk_MCT_SA_HeLa_mDIA_P001_diaP_pydiAID8_1300V_S2-E3_1_1819.d...
# 0:00:16.018792  INFO: Bruker DLL not available, estimating mobility values
# 0:00:16.019510  INFO: Bruker DLL not available, estimating mz values
# 0:00:16.021824  INFO: Indexing quadrupole dimension
# 0:00:16.700933  INFO: Transposing detector events
# 100%|██████████| 20/20 [00:07<00:00,  2.72it/s]
# 0:00:29.116949  INFO: Finished transposing data
# 0:00:29.249609  INFO: Successfully imported data from /Users/georgwallmann/Documents/data/testing/bruker/20230422_TIMS05_PaSk_MCT_SA_HeLa_mDIA_P001_diaP_pydiAID8_1300V_S2-E3_1_1819.d
# 0:00:29.396492  INFO: ========= Initializing Calibration Manager =========
# 0:00:29.397288  INFO: loading calibration config
# 0:00:29.397672  INFO: found 2 calibration groups
# 0:00:29.398352  INFO: Calibration group :fragment, found 1 estimator(s)
# 0:00:29.398835  INFO: Calibration group :precursor, found 3 estimator(s)
# 0:00:29.399090  INFO: ====================================================
# 0:00:29.399645  INFO: ========= Initializing Optimization Manager =========
# 0:00:29.400183  INFO: initial parameter: fwhm_rt = 5
# 0:00:29.400594  INFO: initial parameter: fwhm_mobility = 0.01
# 0:00:29.400852  INFO: ====================================================
# 0:00:29.401218  PROGRESS: Initializing workflow 20230422_TIMS05_PaSk_MCT_SA_HeLa_mDIA_P001_diaP_pydiAID8_1300V_S2-E3_1_1819
# 0:00:29.401613  INFO: ========= Initializing Optimization Manager =========
# 0:00:29.401876  INFO: initial parameter: current_epoch = 0
# 0:00:29.402219  INFO: initial parameter: current_step = 0
# 0:00:29.402592  INFO: initial parameter: ms1_error = 30
# 0:00:29.402870  INFO: initial parameter: ms2_error = 30
# 0:00:29.403346  INFO: initial parameter: rt_error = 240
# 0:00:29.403689  INFO: initial parameter: mobility_error = 0.08
# 0:00:29.404059  INFO: initial parameter: column_type = library
# 0:00:29.404261  INFO: initial parameter: num_candidates = 2
# 0:00:29.404525  INFO: initial parameter: recalibration_target = 200
# 0:00:29.404729  INFO: initial parameter: accumulated_precursors = 0
# 0:00:29.405022  INFO: initial parameter: accumulated_precursors_01FDR = 0
# 0:00:29.405337  INFO: initial parameter: accumulated_precursors_001FDR = 0
# 0:00:29.405687  INFO: ====================================================
# 0:00:29.406021  INFO: ========= Initializing FDR Manager =========
# 0:00:29.406408  INFO: ====================================================
# 0:00:29.406651  PROGRESS: Applying channel filter using only: [0]

# %%
test_df = workflow.spectral_library.precursor_df.sample(1000)

# %%
from alphadia.extraction import hybridselection

config = hybridselection.HybridCandidateConfig()
config.update(workflow.config['selection_config'])
config.update({
    'rt_tolerance':workflow.com.rt_error,
    'mobility_tolerance': workflow.com.mobility_error,
    'candidate_count': workflow.com.num_candidates,
    'precursor_mz_tolerance': workflow.com.ms1_error,
    'fragment_mz_tolerance': workflow.com.ms2_error,
    'exclude_shared_ions': workflow.config['library_loading']['exclude_shared_ions']
})

extraction = hybridselection.HybridCandidateSelection(
    workflow.dia_data.jitclass(),
    test_df,
    workflow.spectral_library.fragment_df,
    config.jitclass(),
    rt_column = f'rt_{workflow.com.column_type}',
    mobility_column = f'mobility_{workflow.com.column_type}',
    precursor_mz_column = f'mz_{workflow.com.column_type}',
    fragment_mz_column = f'mz_{workflow.com.column_type}',
    fwhm_rt = workflow.optimization_manager.fwhm_rt,
    fwhm_mobility = workflow.optimization_manager.fwhm_mobility
)
candidates_df = extraction(
    thread_count=workflow.config['general']['thread_count']
)
# Out:
# 0:04:55.627185  INFO: Duty cycle consists of 9 frames, 0.96 seconds cycle time
# 0:04:55.627841  INFO: Duty cycle consists of 928 scans, 0.00065 1/K_0 resolution
# 0:04:55.628282  INFO: FWHM in RT is 5.00 seconds, sigma is 1.11
# 0:04:55.628570  INFO: FWHM in mobility is 0.010 1/K_0, sigma is 6.57
# 0:04:55.631108  INFO: Starting candidate selection
# 100%|██████████| 1000/1000 [00:10<00:00, 96.39it/s]
# 0:05:06.320512  INFO: Finished candidate selection

# %%
from alphadia.extraction import plexscoring

config = plexscoring.CandidateConfig()
config.update(workflow.config['scoring_config'])
config.update({
    'precursor_mz_tolerance': workflow.com.ms1_error,
    'fragment_mz_tolerance': workflow.com.ms2_error,
    'exclude_shared_ions': workflow.config['library_loading']['exclude_shared_ions']
})

candidate_scoring = plexscoring.CandidateScoring(
    workflow.dia_data.jitclass(),
    workflow.spectral_library._precursor_df,
    workflow.spectral_library._fragment_df,
    config = config,
    rt_column = f'rt_{workflow.com.column_type}',
    mobility_column = f'mobility_{workflow.com.column_type}',
    precursor_mz_column = f'mz_{workflow.com.column_type}',
    fragment_mz_column = f'mz_{workflow.com.column_type}',
)

features_df, fragments_df = candidate_scoring(
    candidates_df, 
    thread_count=workflow.config['general']['thread_count'],
)
# Out:
# 0:05:06.624870  INFO: Starting candidate scoring
# 100%|██████████| 1000/1000 [00:00<00:00, 4020.27it/s]
# 0:05:07.001336  WARNING: delta_frame_peak has 6 NaNs ( 0.60 % out of 1000)
# 0:05:07.032154  INFO: Finished candidate scoring
