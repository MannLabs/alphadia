# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
folder = '/Users/georgwallmann/Documents/data/alphadia_benchmarking/alphadia_runs/2023_04_20_parameter_optimization/'

# %%
sigma_rt_scale_df = pd.read_csv(os.path.join(folder,'sigma_scale_rt_benchmark.tsv'), sep='\t')

fig, ax = plt.subplots(figsize=(6,3))
sns.scatterplot(x='sigma_scale_rt', y='n_precursors', data=sigma_rt_scale_df)
plt.savefig(os.path.join(folder,'sigma_scale_rt_benchmark.png'), dpi=300)

# %%
sigma_mobility_scale_df = pd.read_csv(os.path.join(folder,'sigma_scale_mobility_benchmark.tsv'), sep='\t')

fig, ax = plt.subplots(figsize=(6,3))
sns.scatterplot(x='sigma_scale_mobility', y='n_precursors', data=sigma_mobility_scale_df)
plt.savefig(os.path.join(folder,'sigma_scale_mobility_benchmark.png'), dpi=300)
